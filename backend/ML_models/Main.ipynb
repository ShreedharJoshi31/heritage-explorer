# %%
import pandas as pd

# %%
movies=pd.read_csv('dataset.csv', sep=",", encoding='cp1252')

# %%
movies.head(10)
# Out:
#                          id                                           title  \
# 0  650158346685a6924136861b                                 Aga Khan Palace
# 1  650158346685a6924136861c  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya
# 2  650158346685a6924136861d                     Sanjay Gandhi National Park
# 3  650158346685a6924136861e                                 Elephanta Caves
# 4  650158346685a6924136861f                                     Raigad Fort
# 5  650158346685a69241368620                        Devagiri Daulatabad Fort
# 6  650158346685a69241368621          Veermata Jijabai Bhosale Udyan And Zoo
# 7  650158346685a69241368622                   Dadasaheb Phalke Chitranagari
# 8  650158346685a69241368623                                    Ellora Caves
# 9  650158346685a69241368624                                   Shaniwar Wada
#
#          city                                               desc  \
# 0        Pune  Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1      Mumbai  In 1904, some leading citizens of Bombay decid...
# 2      Mumbai  The Sanjay Gandhi National Park area has a lon...
# 3      Raigad  The authenticity of the property has been well...
# 4      Raigad  The Raigad Fort (earlier called as the Fort of...
# 5  Aurangabad  Quite rightly referred to as one of the ‘Seven...
# 6      Mumbai  Rani Bagh is a fascinating subplot in the hist...
# 7      Mumbai  The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8  Aurangabad  The invaluable ensemble of 34 caves at Ellora ...
# 9        Pune  The foundation stone of the Shaniwar Wada was ...
#
#                                        class
# 0                                Palace,Fort
# 1                                    Library
# 2  National Park, Zoo, Trek, Caves,Adventure
# 3                                Caves, Trek
# 4              Fort, Trek, Historical, Caves
# 5                    Fort, Trek, Adventurous
# 6                         Zoo, National Park
# 7               Museum, FilmCity, Historical
# 8           Caves, Historical Site, Monument
# 9            Palace, Fort, Arcitectural Site

# %%
movies.describe()
# Out:
#                               id            title    city  \
# count                         12               12      12
# unique                        12               12       5
# top     650158346685a6924136861b  Aga Khan Palace  Mumbai
# freq                           1                1       4
#
#                                                      desc        class
# count                                                  12           12
# unique                                                 12           12
# top     Built in 1892 by Sultan Muhammed Shah Aga Khan...  Palace,Fort
# freq                                                    1            1

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      12 non-null     object
#  1   title   12 non-null     object
#  2   city    12 non-null     object
#  3   desc    12 non-null     object
#  4   class   12 non-null     object
# dtypes: object(5)
# memory usage: 612.0+ bytes

# %%
movies.isnull().sum()
# Out:
# id       0
# title    0
# city     0
# desc     0
# class    0
# dtype: int64

# %% [markdown]
# Feature Selection Part

# %%
movies.columns
# Out:
# Index(['id', 'title', 'city', 'desc', 'class'], dtype='object')

# %%
movies=movies[['id', 'title', 'city', 'desc', 'class']]

# %%
movies
# Out:
#                           id                                           title  \
# 0   650158346685a6924136861b                                 Aga Khan Palace
# 1   650158346685a6924136861c  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya
# 2   650158346685a6924136861d                     Sanjay Gandhi National Park
# 3   650158346685a6924136861e                                 Elephanta Caves
# 4   650158346685a6924136861f                                     Raigad Fort
# 5   650158346685a69241368620                        Devagiri Daulatabad Fort
# 6   650158346685a69241368621          Veermata Jijabai Bhosale Udyan And Zoo
# 7   650158346685a69241368622                   Dadasaheb Phalke Chitranagari
# 8   650158346685a69241368623                                    Ellora Caves
# 9   650158346685a69241368624                                   Shaniwar Wada
# 10  650d72ff14a2f4eb24e28989                                     Chand Minar
# 11  650d79e814a2f4eb24eeb2f3                                      New Palace
#
#           city                                               desc  \
# 0         Pune  Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1       Mumbai  In 1904, some leading citizens of Bombay decid...
# 2       Mumbai  The Sanjay Gandhi National Park area has a lon...
# 3       Raigad  The authenticity of the property has been well...
# 4       Raigad  The Raigad Fort (earlier called as the Fort of...
# 5   Aurangabad  Quite rightly referred to as one of the ‘Seven...
# 6       Mumbai  Rani Bagh is a fascinating subplot in the hist...
# 7       Mumbai  The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8   Aurangabad  The invaluable ensemble of 34 caves at Ellora ...
# 9         Pune  The foundation stone of the Shaniwar Wada was ...
# 10  Aurangabad  The Chand Minar whose literal meaning is the "...
# 11    Kolhapur  In the late 19th century a number of buildings...
#
#                                         class
# 0                                 Palace,Fort
# 1                                     Library
# 2   National Park, Zoo, Trek, Caves,Adventure
# 3                                 Caves, Trek
# 4               Fort, Trek, Historical, Caves
# 5                     Fort, Trek, Adventurous
# 6                          Zoo, National Park
# 7                Museum, FilmCity, Historical
# 8            Caves, Historical Site, Monument
# 9             Palace, Fort, Arcitectural Site
# 10                          Architecture Site
# 11                          Palace, Trek,Fort

# %%
movies['tags'] = movies['desc']+movies['city']+movies['class']

# %%
movies
# Out:
#                           id                                           title  \
# 0   650158346685a6924136861b                                 Aga Khan Palace
# 1   650158346685a6924136861c  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya
# 2   650158346685a6924136861d                     Sanjay Gandhi National Park
# 3   650158346685a6924136861e                                 Elephanta Caves
# 4   650158346685a6924136861f                                     Raigad Fort
# 5   650158346685a69241368620                        Devagiri Daulatabad Fort
# 6   650158346685a69241368621          Veermata Jijabai Bhosale Udyan And Zoo
# 7   650158346685a69241368622                   Dadasaheb Phalke Chitranagari
# 8   650158346685a69241368623                                    Ellora Caves
# 9   650158346685a69241368624                                   Shaniwar Wada
# 10  650d72ff14a2f4eb24e28989                                     Chand Minar
# 11  650d79e814a2f4eb24eeb2f3                                      New Palace
#
#           city                                               desc  \
# 0         Pune  Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1       Mumbai  In 1904, some leading citizens of Bombay decid...
# 2       Mumbai  The Sanjay Gandhi National Park area has a lon...
# 3       Raigad  The authenticity of the property has been well...
# 4       Raigad  The Raigad Fort (earlier called as the Fort of...
# 5   Aurangabad  Quite rightly referred to as one of the ‘Seven...
# 6       Mumbai  Rani Bagh is a fascinating subplot in the hist...
# 7       Mumbai  The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8   Aurangabad  The invaluable ensemble of 34 caves at Ellora ...
# 9         Pune  The foundation stone of the Shaniwar Wada was ...
# 10  Aurangabad  The Chand Minar whose literal meaning is the "...
# 11    Kolhapur  In the late 19th century a number of buildings...
#
#                                         class  \
# 0                                 Palace,Fort
# 1                                     Library
# 2   National Park, Zoo, Trek, Caves,Adventure
# 3                                 Caves, Trek
# 4               Fort, Trek, Historical, Caves
# 5                     Fort, Trek, Adventurous
# 6                          Zoo, National Park
# 7                Museum, FilmCity, Historical
# 8            Caves, Historical Site, Monument
# 9             Palace, Fort, Arcitectural Site
# 10                          Architecture Site
# 11                          Palace, Trek,Fort
#
#                                                  tags
# 0   Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1   In 1904, some leading citizens of Bombay decid...
# 2   The Sanjay Gandhi National Park area has a lon...
# 3   The authenticity of the property has been well...
# 4   The Raigad Fort (earlier called as the Fort of...
# 5   Quite rightly referred to as one of the ‘Seven...
# 6   Rani Bagh is a fascinating subplot in the hist...
# 7   The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8   The invaluable ensemble of 34 caves at Ellora ...
# 9   The foundation stone of the Shaniwar Wada was ...
# 10  The Chand Minar whose literal meaning is the "...
# 11  In the late 19th century a number of buildings...

# %%
new_data  = movies.drop(columns=['desc', 'city', 'class'])

# %%
new_data
# Out:
#                           id                                           title  \
# 0   650158346685a6924136861b                                 Aga Khan Palace
# 1   650158346685a6924136861c  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya
# 2   650158346685a6924136861d                     Sanjay Gandhi National Park
# 3   650158346685a6924136861e                                 Elephanta Caves
# 4   650158346685a6924136861f                                     Raigad Fort
# 5   650158346685a69241368620                        Devagiri Daulatabad Fort
# 6   650158346685a69241368621          Veermata Jijabai Bhosale Udyan And Zoo
# 7   650158346685a69241368622                   Dadasaheb Phalke Chitranagari
# 8   650158346685a69241368623                                    Ellora Caves
# 9   650158346685a69241368624                                   Shaniwar Wada
# 10  650d72ff14a2f4eb24e28989                                     Chand Minar
# 11  650d79e814a2f4eb24eeb2f3                                      New Palace
#
#                                                  tags
# 0   Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1   In 1904, some leading citizens of Bombay decid...
# 2   The Sanjay Gandhi National Park area has a lon...
# 3   The authenticity of the property has been well...
# 4   The Raigad Fort (earlier called as the Fort of...
# 5   Quite rightly referred to as one of the ‘Seven...
# 6   Rani Bagh is a fascinating subplot in the hist...
# 7   The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8   The invaluable ensemble of 34 caves at Ellora ...
# 9   The foundation stone of the Shaniwar Wada was ...
# 10  The Chand Minar whose literal meaning is the "...
# 11  In the late 19th century a number of buildings...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (12, 890)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08760058, 0.11399759, 0.01023825, 0.10167554,
#         0.16396995, 0.07027284, 0.0557086 , 0.01292072, 0.1463127 ,
#         0.03042903, 0.13760755],
#        [0.08760058, 1.        , 0.03370361, 0.04035945, 0.07734884,
#         0.05386448, 0.09811031, 0.07116821, 0.02688173, 0.05654593,
#         0.03598561, 0.08218978],
#        [0.11399759, 0.03370361, 1.        , 0.06302535, 0.03294218,
#         0.0180246 , 0.22530753, 0.03492856, 0.11267919, 0.03532086,
#         0.01873172, 0.01283476],
#        [0.01023825, 0.04035945, 0.06302535, 1.        , 0.02465478,
#         0.05396033, 0.0161881 , 0.        , 0.23414542, 0.0475831 ,
#         0.08411582, 0.05763521],
#        [0.10167554, 0.07734884, 0.03294218, 0.02465478, 1.        ,
#         0.1861468 , 0.03384487, 0.01788695, 0.0497831 , 0.14507967,
#         0.18465627, 0.12049942],
#        [0.16396995, 0.05386448, 0.0180246 , 0.05396033, 0.1861468 ,
#         1.        , 0.01851852, 0.06524669, 0.04993865, 0.06350529,
#         0.10905505, 0.11867817],
#        [0.07027284, 0.09811031, 0.22530753, 0.0161881 , 0.03384487,
#         0.01851852, 1.        , 0.07829603, 0.06128834, 0.01360828,
#         0.03849002, 0.        ],
#        [0.0557086 , 0.07116821, 0.03492856, 0.        , 0.01788695,
#         0.06524669, 0.07829603, 1.        , 0.03359043, 0.02397317,
#         0.03390318, 0.02787609],
#        [0.01292072, 0.02688173, 0.11267919, 0.23414542, 0.0497831 ,
#         0.04993865, 0.06128834, 0.03359043, 1.        , 0.03002503,
#         0.0212309 , 0.03394341],
#        [0.1463127 , 0.05654593, 0.03532086, 0.0475831 , 0.14507967,
#         0.06350529, 0.01360828, 0.02397317, 0.03002503, 1.        ,
#         0.08956686, 0.15504051],
#        [0.03042903, 0.03598561, 0.01873172, 0.08411582, 0.18465627,
#         0.10905505, 0.03849002, 0.03390318, 0.0212309 , 0.08956686,
#         1.        , 0.08907453],
#        [0.13760755, 0.08218978, 0.01283476, 0.05763521, 0.12049942,
#         0.11867817, 0.        , 0.02787609, 0.03394341, 0.15504051,
#         0.08907453, 1.        ]])

# %%
new_data[new_data['title']=="Elephanta Caves"].index[0]
# Out:
# 3

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:4]:
    print(new_data.iloc[i[0]].title)
# Out:
# Sanjay Gandhi National Park
# Veermata Jijabai Bhosale Udyan And Zoo
# Aga Khan Palace
# Ellora Caves

# %%
def recommand(movies):
    index=new_data[new_data['title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].id)

# %%
recommand("Raigad Fort")
# Out:
# 650158346685a6924136861f
# 650158346685a69241368620
# 650d72ff14a2f4eb24e28989
# 650158346685a69241368624
# 650d79e814a2f4eb24eeb2f3

# %%
import pickle

# %%
pickle.dump(new_data, open('recommender.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('recommender.pkl', 'rb'))
# Out:
#                           id                                           title  \
# 0   650158346685a6924136861b                                 Aga Khan Palace
# 1   650158346685a6924136861c  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya
# 2   650158346685a6924136861d                     Sanjay Gandhi National Park
# 3   650158346685a6924136861e                                 Elephanta Caves
# 4   650158346685a6924136861f                                     Raigad Fort
# 5   650158346685a69241368620                        Devagiri Daulatabad Fort
# 6   650158346685a69241368621          Veermata Jijabai Bhosale Udyan And Zoo
# 7   650158346685a69241368622                   Dadasaheb Phalke Chitranagari
# 8   650158346685a69241368623                                    Ellora Caves
# 9   650158346685a69241368624                                   Shaniwar Wada
# 10  650d72ff14a2f4eb24e28989                                     Chand Minar
# 11  650d79e814a2f4eb24eeb2f3                                      New Palace
#
#                                                  tags
# 0   Built in 1892 by Sultan Muhammed Shah Aga Khan...
# 1   In 1904, some leading citizens of Bombay decid...
# 2   The Sanjay Gandhi National Park area has a lon...
# 3   The authenticity of the property has been well...
# 4   The Raigad Fort (earlier called as the Fort of...
# 5   Quite rightly referred to as one of the ‘Seven...
# 6   Rani Bagh is a fascinating subplot in the hist...
# 7   The Mumbai Film City or Dadasaheb Phalke Chitr...
# 8   The invaluable ensemble of 34 caves at Ellora ...
# 9   The foundation stone of the Shaniwar Wada was ...
# 10  The Chand Minar whose literal meaning is the "...
# 11  In the late 19th century a number of buildings...
